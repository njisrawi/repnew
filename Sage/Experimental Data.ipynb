# %%
import matplotlib
from pylab import plot, show, xlabel, ylabel, title, grid # For plotting
V_exp = [0.04,0.11,1.89,2.7,4.03,4.94,5.74,6.02,6.21,6.48,6.56,6.62,6.64,6.67,6.71]
I_exp = [-3.9,-3.8,-3.36,-3.0,-2.45,-1.91,-1.19,-0.87,-0.63,-0.29,-0.19,-0.11,-0.08,-0.05,0.0]
# Ploting
plot(V_exp,I_exp)
title('I-V Characteristics For PV Amorphous Si On Glass Solar Cell')
xlabel('V (V)')
ylabel('I (mA)')
grid(True)
show()
