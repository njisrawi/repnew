# %%
350.1^2323230000
# Out:
# 3.10918653332369e5910743437

# %%
integral(sin(x),x)
# Out:
# -cos(x)

# %%
polar_plot(2 + 2*cos(x), (x, 0, 2*pi), color=hue(0.5), thickness=4)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
region_plot(cos(x^2+y^2) <= 0, (x, -3, 3), (y, -3, 3),aspect_ratio=1))
# Out:
#   File "<ipython-input-22-707539cc94a3>", line 1
#     region_plot(cos(x**Integer(2)+y**Integer(2)) <= Integer(0), (x, -Integer(3), Integer(3)), (y, -Integer(3), Integer(3)),aspect_ratio=Integer(1)))
#                                                                                                                                                    ^
# SyntaxError: invalid syntax

# %%
region_plot(cos(x^2+y^2) <= 0, (x, -3, 3), (y, -3, 3),aspect_ratio=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-8a4bae829a38> in <module>()
# ----> 1 region_plot(cos(x**Integer(2)+y**Integer(2)) <= Integer(0), (x, -Integer(3), Integer(3)), (y, -Integer(3), Integer(3)),aspect_ratio=Integer(1))
#
# NameError: name 'y' is not defined
