# %%
4^22
# Out:
# 17592186044416

# %%
(-11)^(3/4.)
# Out:
# -4.27099945527446 + 4.27099945527446*I

# %%
plot(x^2+y^2, (x,-2,2),(y,-2,2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-de1f869c30c8> in <module>()
# ----> 1 plot(x**Integer(2)+y**Integer(2), (x,-Integer(2),Integer(2)),(y,-Integer(2),Integer(2)))
#
# NameError: name 'y' is not defined

# %%
regular = plot(x^2, (x,-2,2), color= 'purple')

# %%
regular
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f(x,y)=y^2+1-x^3-x

# %%
contour_plot(f, (x,-pi,pi), (y,-pi,pi))
# Out:
# Graphics object consisting of 1 graphics primitive
